# %%
import lancedb
lancedb_instance = lancedb.connect("database.lance")

# %%
df = lancedb_instance.open_table("patch14v2_all").to_pandas()

# %%
df.sample(10)
# Out:
#                                                 embedding video_name  \
# 322461  [0.00066041946, -0.002029419, 0.002040863, -0....   L11_V018
# 750368  [-0.008010864, 0.02142334, 0.015792847, -0.002...   L20_V011
# 211160  [0.025558472, 0.011604309, -0.008728027, -0.01...   L08_V001
# 390180  [0.007446289, 0.070617676, 0.016921997, -0.022...   L03_V020
# 94869   [-2.8550625e-05, 0.009086609, 0.029800415, 0.0...   L04_V008
# 852411  [0.012001038, -0.016525269, 0.015563965, -0.00...   L23_V024
# 307010  [-0.025054932, -0.005142212, -0.010948181, -0....   L11_V002
# 265490  [-0.007843018, 0.006313324, 0.0037899017, 0.00...   L09_V022
# 372826  [-0.00730896, 0.04660034, 0.0028877258, -0.002...   L01_V018
# 317103  [0.015174866, -0.0069007874, 0.01940918, -0.00...   L11_V012
#
#                                 image_name  frame_idx  \
# 322461  image-01-scene-214-frame-20336.jpg      20336
# 750368  image-03-scene-321-frame-34809.jpg      34809
# ...
